# %% [markdown]
# ##Agenda
#
# ### 1 Setup
#      1- Create a Catalog, Database(Schema), Volume
#      2- Import Data Ingestion
# ### 2 Creation of Tables/Dataframes
#      1- Tables
#      2- Dtaframes
#      3- Upload data to tables(previously created)

# %% [markdown]
# ![image_1774985632190.png](./image_1774985632190.png "image_1774985632190.png")

# %% [markdown]
# ![image_1774986271380.png](./image_1774986271380.png "image_1774986271380.png")
# ### 1 Setup
#
# ##### 1- Create Catalog, DataBase(Schema), Volume
#    - See Folder  CH02 Setup.
#
#          Notebook "01-setup-environment"

# %% [markdown]
# ##### 2- Import Data Ingestion
#
# ------------------------------------------------
# ##### To ingest data to a Volume in DataBricks  with can go different ways:
#
# 1 By uploading a file from the computer
#
# 2 By downloading a file from a GitHub repository
#
# 3 By connecting to a cloud service(AWS, Azure, etc.)
#
# ------------------------------------------------
# ------------------------------------------------
# ##### To ingest data from a Github account follow teh next notebook
# ------------------------------------------------
#
#    - See Folder  CH02 Setup.
#    - See Folder  utils
#
#          Notebook "data-ingestion"
#
#
#      We use the "utils" folder, with a data-ingestion notebook inside.
#      This notebook contains contains
# -     a class DataLoader() and
# -     a method clean_ingest_data("spark_programmingHBL/data", "spark_programmingHBL/data")
# that would pull the datsets from a GitHub account and will import it to the volume we created.
#
# The GitHub account must have the repository and the directories/folders with the data that will be downloaded from there.
# ###### Repository: --> scholarnest_datasets
# ###### Directory:  --> spark_programmingHBL
# ###### Sub-directory: --> data
# ###### file:      --> diamonds.json
# ###### Full path: --> scholarnest_datasets/spark_programmingHBL/data/diamonds.json
#
# .
#
#
# For this you wil need to pip install and import requests and json
#   -   Installings
#
#                pip3 install requests

# %% [markdown]
# ![image_1774986271380.png](./image_1774986271380.png "image_1774986271380.png")
# ![image_1774985632190.png](./image_1774985632190.png "image_1774985632190.png")
# ### 2 Creation of tables/Dataframes
#
# Thes tables are the ones to be filled with either the data pulled from the import data ingestion or by the files we upload from our computer

# %% [markdown]
# 1 Create empty tables for employees and departments
#
#     Notebook: employee_department_Create_tables_creation
#
# 2 Create empty tables for customers, orders, products, returns
#
#     Notebook: customers_orders_products_returns_tables_Creation
# -----------------------------------------------------------------------------------
# 3 Create dataframes for employees and departments
#
#     NOtebook: employee_department_dataframe_creation.
#               You can directly WORK with these dataframes or
#               Run teh dataframe, copy the data and paste it in a csv file. Then UPLOAD the csv to the VOLUME and use it from there
#
#               UPLOAD -->
#               Click on  to Catalog (dev) , spark_dv, Volumes, Datasets, spark_programming, select 'data' folder.
#               If the file exists then delete it firt: Mark the chekbox next to the desired cvs file and click delete
#               If teh file does not exist then upload it: Click on the top-right "Upload to Volume' bottom and upload files
#
# 4 Create dataframes for customers, orders, products, returns
#
#     Notebook: customer_products_orders_returns_dataframe_Creation
#               You can directly WORK with these dataframes or
#               Run teh dataframe, copy the data and paste it in a csv file. Then UPLOAD the csv to the VOLUME and use it from there
#
#               UPLOAD -->
#               Click on  to Catalog (dev) , spark_dv, Volumes, Datasets, spark_programming, select 'data' folder.
#               If the file exists then delete it firt: Mark the chekbox next to the desired cvs file and click delete
#               If teh file does not exist then upload it: Click on the top-right "Upload to Volume' bottom and upload files
#
# ------------------------------------------------------------------------------------
# 5 Upload the data from those csv files to each of teh tables previously created employee/department
#
#     Notebook: Employee_department-spark-session
#               Read teh CSV
#               Fix any datatype discrepancies
#               Load the data from the csv to each of the tables previously created
#               Query those tables
#
# 6 Upload the data from those csv files to each of teh tables previously created customer/orders/products/returns
#
#     Notebook: customers_products_orders_returns-spark-session
#               Read teh CSV
#               Fix any datatype discrepancies
#               Load the data from the csv to each of the tables previously created
#               Query those tables
