# %% [markdown]
# ## Agenda
#
# The data resulting from each dataframe is then manually copied and pasted into a csv file since I cannot save to csv directly from here
#
# 1 Create spark session
#
# 2 create dataframe
#   * employee
#   * department
#
# 3 Save dataframe to csv file
#   * employee
#   * department

# %% [markdown]
# ### 1 Create spark session

# %%
spark.version
# This above is a pre-created spark session. 
# It's used when you want t avoid creating the spark session with teh builder. "spark" is teh precreated session
# We will use this to create a spark session from here onwards

# This belkow is the way to create a spark session using the builder
#spark_session.version
# Out:
# '4.0.0'

# %%
pip install duckdb pandas # install duckdb and pandas to be able to query a dataframe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 77.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython() # tHIS restarts the kernel or python after running the above command to install duckdb

# %%
import pandas as pd
import duckdb
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DateType
from pyspark.sql.functions import to_date, col

# %% [markdown]
# ### 2 Create dataframe: employee

# %%
data_schema = StructType([
              StructField("employee_id", IntegerType(), True),
              StructField("Name", StringType(), True),
              StructField("departmentid", IntegerType(), True),          
              StructField("role", StringType(), True),                        
              StructField("salary", IntegerType(), True), 
              StructField("startdate", StringType(), True) ,
              StructField("enddate", StringType(), True) 
             ])

data_list  = [
(1,"John Smith"       , 1,    "Sales Associate"       ,60000, "2020-01-15", None),
(2,"Sarah Johnson"    , 1,    "Sales Manager"         ,65000, "2019-06-20", None),
(3,"Michael Brown"    , 2,    "Software Engineer"     ,75000, "2018-03-10", None),
(4,"Emily White"      , 2,    "Software Manager"      ,70000, "2021-02-14", None),
(5,"David Lee"        , 3,    "HR Specialist"         ,80000, "2017-11-25", None),
(6,"Jennifer Davis"   , 3,    "HR Manager"            ,78000, "2019-09-01", "2023-03-30"),
(7,"Robert Wilson"    , None, "Sales Associate"       ,55000, "2022-04-12", None),
(8,"Lisa Anderson"    , 4,    "Marketing Specialist"  ,72000, "2020-07-08", None),
(9,"James Taylor"     , 4,    "Marketing Manager"     ,71000, "2021-01-20", None),
(10,"Mary Martinez"   , None, "Sales Associate"       ,58000, "2022-05-15", None),
(11,"Chris Garcia"    , 1,    "Sales Associate"       ,60000, "2020-10-30", None),
(12,"Paty Rodriz"     , 2,    "Software Engineer"     ,76000, "2019-12-05", None),
(13,"Daniel Thomn"    , None, "Sales Associate"       ,54000, "2023-02-01", None),
(14,"Linda Harris"    , 3,    "HR Specialist"         ,78000, "2018-08-19", None),
(15,"Joseph Clark"    , 4,    "Marketing Specialist"  ,73000, "2021-11-10", None),
(16,"Barbara Lewis"   , None, "Sales Associate"       ,56000, "2022-09-22", None),
(17,"Thomas Walker"   , 1,    "Sales Associate"       ,63000, "2020-03-17", None),
(18,"Susan Hall"      , 2,    "Software Engineer"     ,74000, "2019-07-11", None),
(19,"Charles Allen"   , None, "Sales Associate"       ,59000, "2023-01-08", None),
(20,"Nancy Young"     , 3,    "HR Specialist"         ,81000, "2017-05-30", "2020-05-30"),
(21,"Eva Young"       , 5,    "Finance Manager"       ,80000, "2017-05-30", "2020-06-30"),
(22,"Jeva Chandra"    , 5,    "Finance Specialist"    ,80000, "2017-08-20", None),
(23,"Jim Gallion"     , 6,    "Operations Associate"  ,61000, "2017-08-20", None),
(24,"Juan Lopez"      , 7,    "IT Support Manager"    ,10000, "2018-03-22", None),
(25,"Mina Nakao"      , 8,    "Legal Assistant"       ,81000, "2018-03-20", None),
(26,"Chad Roagen"     , 7,    "IT Support Specialist" ,30000, "2018-03-17", "2026-06-30"),
(27,"Lilly Raied"     , 9,    "Customer Service Rep"  ,40000, "2017-08-20", None),
(28,"Nancy Ledger"    , 6,    "Operations Manager"    ,60000, "2026-07-10", None),
(29,"Benjamin Beneth" , 6,    "Operations Associate"  ,61000, "2026-01-20", None),
(30,"Steven Tanaka"   , 8,    "Legal Manager"         ,80000, "2026-03-20", None),
(31,"Tim Slanter"     , 9,    "Customer Manager"      ,50000, "2026-07-20", None) 
             ]
df = spark.createDataFrame(data=data_list, schema=data_schema)
# Fix date format by first adding "" to convert date into string and then to date due to an isse of teh pspark version 4 not reading the date input and changing a;l dates to 1975
date_cols = {
             "startdate": to_date(col("startdate"), "yyyy-MM-dd"),
             "enddate":   to_date(col("enddate"), "yyyy-MM-dd")
            }

df_fixed =  df.withColumns(date_cols) 
df_fixed.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Create dataframe: department

# %%
data_schema2 = StructType([
                           StructField("departmentname", StringType(), True),
                           StructField("departmentid", IntegerType(), True)
                          ])

data_list2  = [
('Sales'               ,1),
('Engineering'         ,2),
('HR'                  ,3),
('Marketing'           ,4),
('Finance'             ,5),
('Operations'          ,6),
('IT Support'          ,7),
('Legal'               ,8),
('Customer Service'    ,9),
('Product Management'  ,10),
('Social Media'        ,11)              
             ]
df2 = spark.createDataFrame(data=data_list2, schema=data_schema2)

df2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>departmentname</th><th>departmentid</th></tr></thead><tbody><tr><td>Sales</td><td>1</td></tr><tr><td>Engineering</td><td>2</td></tr><tr><td>HR</td><td>3</td></tr><tr><td>Marketing</td><td>4</td></tr><tr><td>Finance</td><td>5</td></tr><tr><td>Operations</td><td>6</td></tr><tr><td>IT Support</td><td>7</td></tr><tr><td>Legal</td><td>8</td></tr><tr><td>Customer Service</td><td>9</td></tr><tr><td>Product Management</td><td>10</td></tr><tr><td>Social Media</td><td>11</td></tr></tbody></table></div>

# %% [markdown]
# ### 3 Save dataframe to csv file
